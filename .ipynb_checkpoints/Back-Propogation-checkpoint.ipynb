# %% [markdown]
# # CONVOLUTION NETS

# %%
import numpy as np

# %%
class Bpn():
    def sigmoid(self,z):
        return (1/(1+np.exp(-z)))
    def linear(self,weights,inpu):
        return np.dot(np.transverse(weights),inpu)

# %%
bp = Bpn()
bp.sigmoid(0)
# Out:
# 0.5
