# %%
N=10
inp = int(input())
if inp>0 and inp<=5:
    print("NUMBER OF CANDIES SOLD:{}".format(inp))
    print("NUMBER OF CANDIES AVAILABLE:{}".format(N-inp))
else:
    print("INVALID INPUT")
    print("NUMBER OF CANDIES AVAILABLE:{}".format(N))

# %%
one,two,three =[],[],[]
one.append(int(input()))
two.append(int(input()))
three.append(int(input()))
one.append(int(input()))
two.append(int(input()))
three.append(int(input()))
one.append(int(input)())
two.append(int(input()))
three.append(int(input()))
avg = []
avg.append(sum(one)/3)
avg.append(sum(two)/3)
avg.append(sum(three)/3)
final = max(avg)
if avg[0]<70 and avg[1]<70 and avg[2]<70:
    print('All trainees are unfit')            
else avg[0]== final:
    print('Trainee Number: 1')
else avg[1] == final:
    print('Trainee Number: 2')
else avg[2] == final:
    print('Trainee Number: 3')
